# %% [markdown]
# # Gold Price Forecast based on LSTM-CNN Model

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import sklearn.preprocessing
import sklearn.model_selection
import tensorflow as tf

# %%
# Load dataset
# df = pd.read_csv("/Users/luke/Desktop/美赛/MCM-ICM-2022/2022_Problem_C_DATA/BCHAIN-MKPRU.csv")
df = pd.read_csv("/Users/luke/Desktop/美赛/MCM-ICM-2022/2022_Problem_C_DATA/LBMA-GOLD.csv")

# %%
# Model settings
alpha = 7   # window length
beta = 1    # the number of LSTM layers
gamma = 64  # the number of filters in convolutional layer

# %%
prices = df['USD (PM)'].tolist()
# prices = df['Value'].tolist()

prices = [x for x in prices if str(x) != 'nan'] # delete nan

# Split data
training_ratio = 0.2
test_ratio = 0.2
n_train = int(len(prices) * training_ratio)
n_test = int(len(prices) * test_ratio)

train_prices = np.array(prices[:n_train]).reshape((-1, 1))
test_prices = np.array(prices[n_train:n_train+n_test]).reshape((-1, 1))

# Standardize data
scaler = sklearn.preprocessing.StandardScaler()
scaler.fit(train_prices)
train_prices = scaler.transform(train_prices).reshape(-1)
test_prices = scaler.transform(test_prices).reshape(-1)

print("train_prices.shape:", train_prices.shape)
print("test_prices.shape:", test_prices.shape)
# Out:
# train_prices.shape: (251,)
# test_prices.shape: (251,)

# %%
# make train dataset
X_train = []
y_train = []
for i in range(len(train_prices)-alpha):
    X_train.append(train_prices[i:i+alpha].reshape((1, -1)))
    y_train.append(train_prices[i+alpha].reshape((1, -1)))  # next day's price
X_train = np.array(X_train, dtype='float32')
y_train = np.array(y_train, dtype='float32')

# make test dataset
X_test = []
y_test = []
for i in range(len(test_prices)-alpha):
    X_test.append(test_prices[i:i+alpha].reshape((1, -1)))
    y_test.append(test_prices[i+alpha].reshape((1, -1)))  # next day's price
X_test = np.array(X_test, dtype='float32')
y_test = np.array(y_test, dtype='float32')

print("X_train.shape:", X_train.shape)
print("y_train.shape:", y_train.shape)
print("X_test.shape:", X_test.shape)
print("y_test.shape:", y_test.shape)
# Out:
# X_train.shape: (244, 1, 7)
# y_train.shape: (244, 1, 1)
# X_test.shape: (244, 1, 7)
# y_test.shape: (244, 1, 1)

# %%
# Plot dataset
plt.figure(figsize=(16, 4))
plt.subplot(121)
plt.title("X_train[:, 0, 0] (%d ~ %d)" % (0, len(X_train)-1))
sns.lineplot(x=np.arange(0, len(X_train)), y=X_train[:, 0, 0])

plt.subplot(122)
plt.title("X_test[:, 0, 0] (%d ~ %d)" % (len(X_train), len(X_train)+len(X_test)-1))
sns.lineplot(x=np.arange(len(X_train), len(X_train)+len(X_test)), y=X_test[:, 0, 0])
plt.show()

# %%
model = tf.keras.models.Sequential([
    tf.keras.layers.LSTM(alpha, input_shape=(1, alpha), return_sequences=True) for _ in range(beta)
] + [
    # attention.Attention(),
    tf.keras.layers.Dense(alpha, activation='linear'),
    tf.keras.layers.Reshape((1, alpha)),
    tf.keras.layers.Conv1D(filters=gamma, kernel_size=1, strides=1),
    tf.keras.layers.MaxPooling1D(pool_size=2, strides=1, padding='same'),
    tf.keras.layers.Dense(alpha, activation='relu'),
    tf.keras.layers.Dense(1, activation='linear'),
])
# model.summary()
# model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.001), loss='mse')
model.compile(optimizer='adam', loss='mse')
history = model.fit(X_train, y_train, batch_size=64, epochs=80)
# Out:
# Epoch 1/80
# 2022-02-19 16:22:19.130994: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2022-02-19 16:22:19.275540: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2022-02-19 16:22:19.586288: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 4/4 [==============================] - 2s 87ms/step - loss: 0.9592
# Epoch 2/80
# 4/4 [==============================] - 0s 50ms/step - loss: 0.9198
# Epoch 3/80
# 4/4 [==============================] - 0s 24ms/step - loss: 0.8905
# Epoch 4/80
# 4/4 [==============================] - 0s 24ms/step - loss: 0.8590
# Epoch 5/80
# 4/4 [==============================] - 0s 15ms/step - loss: 0.8220
# Epoch 6/80
# 4/4 [==============================] - 0s 13ms/step - loss: 0.7806
# Epoch 7/80
# 4/4 [==============================] - 0s 16ms/step - loss: 0.7331
# Epoch 8/80
# 4/4 [==============================] - 0s 15ms/step - loss: 0.6810
# Epoch 9/80
# 4/4 [==============================] - 0s 21ms/step - loss: 0.6267
# Epoch 10/80
# 4/4 [==============================] - 0s 14ms/step - loss: 0.5695
# Epoch 11/80
# 4/4 [==============================] - 0s 15ms/step - loss: 0.5056
# Epoch 12/80
# 4/4 [==============================] - 0s 12ms/step - loss: 0.4452
# Epoch 13/80
# 4/4 [==============================] - 0s 13ms/step - loss: 0.3889
# Epoch 14/80
# 4/4 [==============================] - 0s 14ms/step - loss: 0.3345
# Epoch 15/80
# 4/4 [==============================] - 0s 16ms/step - loss: 0.2829
# Epoch 16/80
# 4/4 [==============================] - 0s 14ms/step - loss: 0.2437
# Epoch 17/80
# 4/4 [==============================] - 0s 13ms/step - loss: 0.2111
# Epoch 18/80
# 4/4 [==============================] - 0s 16ms/step - loss: 0.1900
# Epoch 19/80
# 4/4 [==============================] - 0s 12ms/step - loss: 0.1797
# Epoch 20/80
# 4/4 [==============================] - 0s 12ms/step - loss: 0.1744
# Epoch 21/80
# 4/4 [==============================] - 0s 13ms/step - loss: 0.1692
# Epoch 22/80
# 4/4 [==============================] - 0s 13ms/step - loss: 0.1621
# Epoch 23/80
# 4/4 [==============================] - 0s 15ms/step - loss: 0.1549
# Epoch 24/80
# 4/4 [==============================] - 0s 12ms/step - loss: 0.1468
# Epoch 25/80
# 4/4 [==============================] - 0s 12ms/step - loss: 0.1393
# Epoch 26/80
# 4/4 [==============================] - 0s 12ms/step - loss: 0.1339
# Epoch 27/80
# 4/4 [==============================] - 0s 13ms/step - loss: 0.1272
# Epoch 28/80
# 4/4 [==============================] - 0s 12ms/step - loss: 0.1221
# Epoch 29/80
# 4/4 [==============================] - 0s 13ms/step - loss: 0.1160
# Epoch 30/80
# 4/4 [==============================] - 0s 12ms/step - loss: 0.1111
# Epoch 31/80
# 4/4 [==============================] - 0s 14ms/step - loss: 0.1060
# Epoch 32/80
# 4/4 [==============================] - 0s 13ms/step - loss: 0.1016
# Epoch 33/80
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0977
# Epoch 34/80
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0947
# Epoch 35/80
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0909
# Epoch 36/80
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0879
# Epoch 37/80
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0854
# Epoch 38/80
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0831
# Epoch 39/80
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0810
# Epoch 40/80
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0795
# Epoch 41/80
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0780
# Epoch 42/80
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0768
# Epoch 43/80
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0758
# Epoch 44/80
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0744
# Epoch 45/80
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0732
# Epoch 46/80
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0721
# Epoch 47/80
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0712
# Epoch 48/80
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0701
# Epoch 49/80
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0693
# Epoch 50/80
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0682
# Epoch 51/80
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0673
# Epoch 52/80
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0664
# Epoch 53/80
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0659
# Epoch 54/80
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0649
# Epoch 55/80
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0641
# Epoch 56/80
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0634
# Epoch 57/80
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0626
# Epoch 58/80
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0619
# Epoch 59/80
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0614
# Epoch 60/80
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0607
# Epoch 61/80
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0601
# Epoch 62/80
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0594
# Epoch 63/80
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0586
# Epoch 64/80
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0579
# Epoch 65/80
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0576
# Epoch 66/80
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0571
# Epoch 67/80
# 4/4 [==============================] - 0s 25ms/step - loss: 0.0565
# Epoch 68/80
# 4/4 [==============================] - 0s 16ms/step - loss: 0.0559
# Epoch 69/80
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0555
# Epoch 70/80
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0550
# Epoch 71/80
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0547
# Epoch 72/80
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0543
# Epoch 73/80
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0539
# Epoch 74/80
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0540
# Epoch 75/80
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0535
# Epoch 76/80
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0530
# Epoch 77/80
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0528
# Epoch 78/80
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0525
# Epoch 79/80
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0522
# Epoch 80/80
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0521

# %%
plt.figure(figsize=(16, 8))
sns.lineplot(data=history.history)
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.title("Loss")
plt.show()

# %%
preds = model.predict(X_test)
# Out:
# 2022-02-19 16:22:24.651109: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2022-02-19 16:22:24.696126: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.

# %%
plt.figure(figsize=(16, 8))
sns.lineplot(data={
    "actual data": scaler.inverse_transform(y_test.reshape(-1, 1)).reshape(-1),
    "prediction": scaler.inverse_transform(preds.reshape(-1, 1)).reshape(-1),
})
plt.title("Comparison between actual data and prediction")
plt.xlabel("Time")
plt.ylabel("Dollar")
plt.show()
